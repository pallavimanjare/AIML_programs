# %%
# Datatypes ------ Datatypes define the type of the data a VARIABLE can HOLD / MAINTAIN.
# Datatypes ------ 1.Primitive Types
#                  2. Collections
#
#                             Primitive Types
#                                   |
#    --------------------------------------------------------------------------------
#    |                              |                                               |
#  Numbers                        Strings                                       Boolean
#    |                              (str)                                          (bool)
#  ------------------------
#  |          |           |
# Integers   Decimals   Complex
# (int)      (float)    (complex)

# %%
#To execute a cell, ----- Ctrl+Enter
#To execute current cell and create new cell below ----- Shift + Enter

# %%
# Python is a Type Inferred Language
# Type Inference - Assigning Datatype to a variable automatically based on the value supplied
num1 = 10

# %%
type(num1)
# Out:
# int

# %%
num2 = 3+4j
type(num2)
# Out:
# complex

# %%
num3 = "Prashant"
type(num3)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
# https://www.w3schools.com/python/python_datatypes.asp
