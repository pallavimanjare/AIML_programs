# %%
# User Interaction
# Accept value/data from user and store it in a variable
# input() ----> responsible to accept the data from the user and store the data in the form of STRING

# %%
name = input("Enter your name: ")
print(f"Hello {name} ! Welcome to my Python Class :) ")
# Out:
# Enter your name: Prashant
# Hello Prashant ! Welcome to my Python Class :)

# %%
type(name)
# Out:
# str

# %%
#Simple Addition of Two Numbers

#Typecasting ---- Converting the datatype of a variable from one form to another
#                 ensuring the fact, the value complys the datatype


num1 = int(input("Enter first Number: ") )
num2 = int(input("Enter second Number: "))

result = num1 + num2

print(f"The addition of {num1} and {num2} is {result}")
# Out:
# Enter first Number: 3
# Enter second Number: 4
# The addition of 3 and 4 is 7

# %%
type(num1)
# Out:
# int

# %%
test = "45ce"
type(test)
# Out:
# str

# %%
result = int(test)
type(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c9627d2328fc> in <cell line: 1>()
# ----> 1 result = int(test)
#       2 type(result)
#
# ValueError: invalid literal for int() with base 10: '45ce'

# %%
num1 = input("Enter number one: ")
num2 = input ("Enter number two: ")

Result = num1 + num2

print(f"The addition of {num1} and {num2} is {Result}")
# Out:
# Enter number one: 5
# Enter number two: 6
# The addition of 5 and 6 is 56
