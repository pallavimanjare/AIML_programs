# %%
#print() is used to print the value of the variable

# %%
num1 = 10

# %%
num1
# Out:
# 10

# %%
print(num1)
# Out:
# 10

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
print(" We are learning 'Python' Language")
# Out:
#  We are learning 'Python' Language

# %%
#Escape characters ----- \
print(' We are learning \'Python\' Language')
print("We are learning \"Python\" Language This is a test")
# Out:
#  We are learning 'Python' Language
# We are learning "Python" Language This is a test

# %%
#Triple Quote
# Used for Multi-line Printing
#


print("""
     ==============================
         McDonalds Restaurant
       XYZ location , CA - 1111
     ==============================

     1. McChicken Burger  - $5

     Total:                 $5

    ================================

""")
# Out:
# ...
#          McDonalds Restaurant
#        XYZ location , CA - 1111
# ...
#
#      1. McChicken Burger  - $5
#
#      Total:                 $5
#
# ...

# %%
#Use a variable in a string for printing

num1 = 10
print("Given number is ", num1)
# Out:
# Given number is  10

# %%
#Using format()

num1 = 10
num2 = 20

print(" The given two numbers are {} and {} respectively".format(num1,num2))
# Out:
#  The given two numbers are 10 and 20 respectively

# %%
#Using Formatted Strings

num1 = 10
num2 = 20

print(f" The given two numbers are { num1 } and { num2 } respectively")
# Out:
#  The given two numbers are 10 and 20 respectively

# %%
num1 = 10
num2 = 35

print(f" The given two numbers are { num1 } and { num2 } respectively, so print it")
# Out:
#  The given two numbers are 10 and 35 respectively, so print it

# %%
num3 = 25
print(f"The value of {num2} and {num3}")
# Out:
# The value of 35 and 25
