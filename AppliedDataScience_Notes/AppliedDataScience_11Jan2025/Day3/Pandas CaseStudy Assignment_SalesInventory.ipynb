# %%
#Pandas Case Study Assignment
#Case Study: Sales and Inventory Analysis

#You are working as a Data Analyst for an e-commerce company. The company wants to analyze sales and inventory data to make better business decisions. You have two datasets:
#Sales Data (sales.csv)Contains records of customer purchases.
#Inventory Data (inventory.csv)Contains stock information for products.

# %%
#Assignment Questions

#Section 1: Data Integration (3 Questions)

# %%
#1. Combine the details from the sales and inventory datasets based on common product identifiers and analyze the output.

# %%
#2. Ensure that all sales records are retained while incorporating matching product details from the inventory data.

# %%
#3. Identify products available in the inventory that have not been sold yet and display the results.

# %%
#Section 2: Expanding Data (3 Questions)

# %% [markdown]
# A new batch of sales transactions has been recorded. Integrate the following records with the existing sales dataset:
#
# ![image.png](data:image/png;base64,...)

# %%
#2. Attempt to append the sales and inventory datasets together without specifying a key. What do you observe?

# %%
#3.A new set of product inventory details has been received. Integrate this new data with the existing inventory dataset.

# %%
#Section 3: Data Modification (3 Questions)

# %%
#1. Remove the transaction associated with Order_ID = 103 and display the updated records.

# %%
#2. Identify and exclude all sales where fewer than 2 units were purchased.

# %%
#3. For customers making multiple purchases, keep only the first transaction in the dataset.

# %%
#Section 4: Adjusting Data Structure (3 Questions)
#
#1. Modify the sales dataset to exclude any pricing details.

# %%
#2. Revise the inventory dataset to retain only product-related information while removing stock-specific details.

# %%
#3. Retain only essential sales details, focusing on Order_ID, Product_ID, and Quantity.

# %%
#Section 5: Group-Based Insights (3 Questions)

# %%
# 1. Determine the total number of items each customer has purchased.

# %%
#2. Calculate the revenue generated for each product based on sales transactions.

# %%
# 3. Assess the total stock count for each product category.
